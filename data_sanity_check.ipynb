# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Consts etc.
data_path = "data/"

# %% [markdown]
# # Experiment 1

# %%
e1_file_names = ["experiment 1 run 1.txt", "experiment 1 run 2.txt", "experiment 1 run 3.txt"]
e1_data = []

for file_name in e1_file_names:
    file_path = data_path + file_name
    db_temp = pd.read_csv(file_path, sep="\t", decimal=",", header=None)

    e1_column_names = db_temp.iloc[0]
    e1_units = db_temp.iloc[1]

    db_temp = db_temp[2:]
    db_temp.columns = e1_column_names

    db_temp = db_temp.apply(lambda col: col.str.replace(",", ".").astype(float) if col.dtype == "object" else col)
    e1_data.append(db_temp)

# Test
print(e1_data[0].head())
print(len(e1_data[0]["Tijd"]))
print(len(e1_data[0]["Ch1"]))
# Out:
# 0   Tijd     Ch1     Ch2
# 2  0.000  1019.0  1007.0
# 3  0.455  1019.0  1007.0
# 4  1.089  1019.0  1007.0
# 5  2.088  1019.0  1007.0
# 6  3.088  1019.0  1007.0
# 1079
# 1079

# %%
# Adjust the the data to match the other runs
e1_data[0] = e1_data[0].iloc[770:]

# Plot test 1 to extract relevant part
plt.figure(figsize=(10, 5))
plt.scatter(e1_data[0]['Tijd'], e1_data[0]['Ch1'], label='Ch1', s=5)
plt.scatter(e1_data[0]['Tijd'], e1_data[0]['Ch2'], label='Ch2', s=5)

plt.xlabel('Time [s]')
plt.ylabel('Pressure [mBar]')
plt.title('Experiment 1 Run 1')

plt.legend()
plt.show()

# Note to self: Drop seems to be around 750-780 s -> (770 s is the answer)

# %%
# Adjust the the data to match the other runs
e1_data[1] = e1_data[1].iloc[3:]

# Plot test 1 to extract relevant part
plt.figure(figsize=(10, 5))
plt.scatter(e1_data[1]['Tijd'], e1_data[1]['Ch1'], label='Ch1', s=5)
plt.scatter(e1_data[1]['Tijd'], e1_data[1]['Ch2'], label='Ch2', s=5)

plt.xlabel('Time [s]')
plt.ylabel('Pressure [mBar]')
plt.title('Experiment 1 Run 2')

plt.legend()
plt.show()

# Note to self: Just cut-off the first few seconds, drop is almost immediate -> (three seconds is the answer)

# %%
# Adjust the the data to match the other runs
e1_data[1] = e1_data[1].iloc[1:]

# Plot test 1 to extract relevant part
plt.figure(figsize=(10, 5))
plt.scatter(e1_data[2]['Tijd'], e1_data[2]['Ch1'], label='Ch1', s=5)
plt.scatter(e1_data[2]['Tijd'], e1_data[2]['Ch2'], label='Ch2', s=5)

plt.xlabel('Time [s]')
plt.ylabel('Pressure [mBar]')
plt.title('Experiment 1 Run 3')

plt.legend()
plt.show()

# Note to self: Just cut-off the first few seconds, drop is almost immediate -> (1 second is the answer)

# %% [markdown]
# # Experiment 2

# %%
e2_datas = {}
for D in [2,3,4]:
    e2_file_names = [f"experiment 2 {D}mm run {i}.txt" for i in range(1, 3+1)]
    e2_data = []

    for file_name in e2_file_names:
        file_path = data_path + file_name
        db_temp = pd.read_csv(file_path, sep="\t", decimal=",", header=None)

        e2_column_names = db_temp.iloc[0]
        e2_units = db_temp.iloc[1]

        db_temp = db_temp[2:]
        db_temp.columns = e2_column_names

        db_temp = db_temp.apply(lambda col: col.str.replace(",", ".").astype(float) if col.dtype == "object" else col)
        e2_data.append(db_temp)
    
    e2_datas[f"{D}mm"] = e2_data

# Test
print(e2_datas["2mm"][0].head())
# Out:
# 0   Tijd     Ch1     Ch2
# 2  0.000  1031.0  1018.0
# 3  0.452  1031.0  1018.0
# 4  1.362  1030.0  1018.0
# 5  2.363  1030.0  1018.0
# 6  3.363   512.0  1014.0

# %% [markdown]
# ## 2mm

# %%
for i in range(1, 3+1):
    plt.figure(figsize=(10, 5))
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch1'], label='Ch1', s=5)
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch2'], label='Ch2', s=5)

    plt.xlabel('Time [s]')
    plt.ylabel('Pressure [TODO]')
    plt.title(f'Experiment 2 2mm Run {i}')

    plt.xticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Tijd']), step=100))
    plt.yticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Ch1']), step=100))

    plt.legend()
    plt.show()

# %% [markdown]
# ## 3 mm

# %%
for i in range(1, 3+1):
    plt.figure(figsize=(10, 5))
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch1'], label='Ch1', s=5)
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch2'], label='Ch2', s=5)

    plt.xlabel('Time [s]')
    plt.ylabel('Pressure [TODO]')
    plt.title(f'Experiment 2 2mm Run {i}')

    plt.xticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Tijd']), step=100))
    plt.yticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Ch1']), step=100))

    plt.legend()
    plt.show()

# %% [markdown]
# ## 4 mm

# %%
for i in range(1, 3+1):
    plt.figure(figsize=(10, 5))
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch1'], label='Ch1', s=5)
    plt.scatter(e2_datas["2mm"][i-1]['Tijd'], e2_datas["2mm"][i-1]['Ch2'], label='Ch2', s=5)

    plt.xlabel('Time [s]')
    plt.ylabel('Pressure [TODO]')
    plt.title(f'Experiment 2 2mm Run {i}')

    plt.xticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Tijd']), step=100))
    plt.yticks(ticks=np.arange(0, len(e2_datas["2mm"][i-1]['Ch1']), step=100))

    plt.legend()
    plt.show()
